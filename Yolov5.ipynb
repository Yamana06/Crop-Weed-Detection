# %% [markdown]
# <a href="https://colab.research.google.com/github/Athulya2/crop-and-weed-detection/blob/main/Yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -U -r yolov5/requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12375, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 12375 (delta 22), reused 13 (delta 5), pack-reused 12335
# Receiving objects: 100% (12375/12375), 12.18 MiB | 30.79 MiB/s, done.
# Resolving deltas: 100% (8535/8535), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 60.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 48.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 31.6 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 776.3 MB 20 kB/s
# ...
#      |████████████████████████████████| 19.1 MB 956 kB/s
# ...
#      |████████████████████████████████| 407 kB 74.0 MB/s
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/yolov5/train.py --img 416 --batch 16 --epochs 100  --data new_data_yaml.yaml --cfg new_train_yaml.yaml
# Out:
# train: weights=yolov5s.pt, cfg=new_train_yaml.yaml, data=new_data_yaml.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-274-gda2ee39 Python-3.7.13 torch-1.12.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
#!python /content/yolov5/detect.py  --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 416 --conf 0.6 --save-txt
# !python /content/yolov5/detect.py --source '/content/yolov5/weed_1.jpeg' --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 416 --conf 0.5 --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/weed_1.jpeg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-274-gda2ee39 Python-3.7.13 torch-1.12.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# new_train_yaml summary: 232 layers, 7249215 parameters, 0 gradients, 16.7 GFLOPs
# image 1/1 /content/yolov5/weed_1.jpeg: 416x416 1 weed, Done. (0.009s)
# Speed: 0.4ms pre-process, 9.4ms inference, 1.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp5
